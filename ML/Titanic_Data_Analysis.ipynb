# %% [markdown]
# This are the libary that we need to analysis a a Dataset

# %% [markdown]
# # New Section

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load the Dataset form a datafile(CSV)

# %%
t_data=pd.read_csv("/content/titanic.csv")

# %% [markdown]
# Now show the top 10 row form this dataset

# %%
t_data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
print("Total no of passanger in original data is: "+str(len(t_data.index)))
# Out:
# Total no of passanger in original data is: 891

# %%
t_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# **Analyzing the Data**

# %%
sns.countplot(x="Survived",data=t_data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Survived",hue="Sex",data=t_data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Survived",hue="Pclass",data=t_data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
titanic_data["Age"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.countplot(x="Survived",hue="SibSp",data=t_data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# **Data Warnling**(Clen the data by removing null values and unnecessary column form the dataset)

# %% [markdown]
# Check the which data set's are NULL

# %%
t_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Create a heatmap of the missing values
sns.heatmap(t_data.isnull(), cmap='flag_r')
# Out:
# <Axes: >

# %%
sns.boxplot(x="Pclass",y="Age",data=t_data)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
t_data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
t_data.drop("Ticket",axis=1,inplace=True)

# %%
t_data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Cabin Embarked
# 0      0   7.2500   NaN        S
# 1      0  71.2833   C85        C
# 2      0   7.9250   NaN        S
# 3      0  53.1000  C123        S
# 4      0   8.0500   NaN        S

# %%
t_data.dropna(inplace=True)

# %%
t_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
sns.heatmap(t_data.isnull(), cmap='flag_r')
# Out:
# <Axes: >

# %%
sex=pd.get_dummies(t_data["Sex"],drop_first=True)
sex.head(5)
# Out:
#      male
# 1   False
# 3   False
# 6    True
# 10  False
# 11  False

# %%
t_data.head(5)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch     Fare Cabin Embarked
# 1       0  71.2833   C85        C
# 3       0  53.1000  C123        S
# 6       0  51.8625   E46        S
# 10      1  16.7000    G6        S
# 11      0  26.5500  C103        S

# %%
embark=pd.get_dummies(t_data["Embarked"],drop_first=True)

# %%
embark.head(5)
# Out:
#         Q      S
# 1   False  False
# 3   False   True
# 6   False   True
# 10  False   True
# 11  False   True

# %%
Pcls=pd.get_dummies(t_data["Pclass"],drop_first=True)

# %%
Pcls.head(5)
# Out:
#     2  3
# 1   0  0
# 3   0  0
# 6   0  0
# 10  0  1
# 11  0  0

# %% [markdown]
# **Now we have to concatinate the data into our dataset.**
